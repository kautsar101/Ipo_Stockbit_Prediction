# %%
import pandas as pd
df = pd.read_csv("Doc//ipodata.csv")

# %%
df2 = pd.read_csv("Doc//ipo_gain.csv")

# %%
df_merge = pd.concat([df,df2],axis=1)
df_merge.head(1)
# Out:
#    Code                          Name         Date  Price Share  \
# 0  GUNA  PT. Gunanusa Eramandiri Tbk.  09 Jul 2024  Rp150   20%
#
#           Amount Warran                Underwriter                  Sector  \
# 0  5,000,000 lot      0  GR - PANIN SEKURITAS TBK.  Barang Konsumen Primer
#
#            Subsector  ... 1 candle gain 2 candle gain 3 candle gain  \
# 0  Makanan & Minuman  ...     34.666667          68.0    109.333333
#
#   4 candle gain 5 candle gain 1 candle high 2 candle high  3 candle high  \
# 0     98.666667     94.666667     34.666667          68.0     109.333333
#
#    4 candle high  5 candle high
# 0     161.333333          116.0
#
# [1 rows x 27 columns]

# %%
len(df_merge["Underwriter"].value_counts())
# Out:
# 34

# %%
ARA = df_merge.query('`1 candle high` > 34')[["Code","1 candle high","Underwriter","Papan Pencatatan"]]

# %%
len(ARA)
# Out:
# 76

# %%
df_merge["Papan Pencatatan"].value_counts()
# Out:
# Papan Pencatatan
# Pengembangan         94
# Utama                36
# Akselerasi           31
# Pemantauan Khusus    16
# Ekonomi Baru          2
# Name: count, dtype: int64

# %%
ARA["Papan Pencatatan"].value_counts()
# Out:
# Papan Pencatatan
# Pengembangan         55
# Pemantauan Khusus    13
# Utama                 8
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
df_merge[["Code","Underwriter"]]
# Out:
#      Code                             Underwriter
# 0    GUNA               GR - PANIN SEKURITAS TBK.
# 1    GOLF         IF - SAMUEL SEKURITAS INDONESIA
# 2    LABS            YJ - LOTUS ANDALAN SEKURITAS
# 3    ISEA        CP - VALBURY SEKURITAS INDONESIA
# 4    PART                      EP - MNC SEKURITAS
# 5    BLES            YJ - LOTUS ANDALAN SEKURITAS
# 6    SPRE                      EP - MNC SEKURITAS
# 7    BATR            HD - KGI SEKURITAS INDONESIA
# 8    SOLA             AI - UOB KAY HIAN SEKURITAS
# 9    DATA             AI - UOB KAY HIAN SEKURITAS
# 10   MHKI     XA - NH KORINDO SEKURITAS INDONESIA
# 11   ATLA          SH - ARTHA SEKURITAS INDONESIA
# 12   AREA               GR - PANIN SEKURITAS TBK.
# 13   VISI              SF - SURYA FAJAR SEKURITAS
# 14   LIVE         IF - SAMUEL SEKURITAS INDONESIA
# 15   BAIK                      EP - MNC SEKURITAS
# 16   HYGN            HD - KGI SEKURITAS INDONESIA
# 17   MKAP            YJ - LOTUS ANDALAN SEKURITAS
# 18   MEJA                      EP - MNC SEKURITAS
# 19   ALII           KI - CIPTADANA SEKURITAS ASIA
# 20   MPIX            DR - RHB SEKURITAS INDONESIA
# 21   TOSK                      EP - MNC SEKURITAS
# 22   UNTD    YP - MIRAE ASSET SEKURITAS INDONESIA
# 23   SMGA       MI - VICTORIA SEKURITAS INDONESIA
# 24   GRPH              SA - ELIT SUKSES SEKURITAS
# 25   MSJA            OD - BRI DANAREKSA SEKURITAS
# 26   NICE             AI - UOB KAY HIAN SEKURITAS
# 27   ACRO             AI - UOB KAY HIAN SEKURITAS
# 28   SMLE                      EP - MNC SEKURITAS
# 29   CGAS      PO - PILARMAS INVESTINDO SEKURITAS
# 30   MANG             PG - PANCA GLOBAL SEKURITAS
# 31   ASLI     XA - NH KORINDO SEKURITAS INDONESIA
# 32   SURI        AH - SHINHAN SEKURITAS INDONESIA
# 33   AYAM             AI - UOB KAY HIAN SEKURITAS
# 34   MSTI             PD - INDO PREMIER SEKURITAS
# 35   IKPM           TP - OCBC SEKURITAS INDONESIA
# 36   RGAS             AO - ERDIKHA ELIT SEKURITAS
# 37   UDNG                      EP - MNC SEKURITAS
# 38   LOPI              SA - ELIT SUKSES SEKURITAS
# 39   PTPS     XA - NH KORINDO SEKURITAS INDONESIA
# 40   KOKA             AI - UOB KAY HIAN SEKURITAS
# 41   BREN                      NI - BNI SEKURITAS
# 42   IOTF        AH - SHINHAN SEKURITAS INDONESIA
# 43   KOCI             PG - PANCA GLOBAL SEKURITAS
# 44   STRK          SH - ARTHA SEKURITAS INDONESIA
# 45   AEGS        AH - SHINHAN SEKURITAS INDONESIA
# 46   BABY             AI - UOB KAY HIAN SEKURITAS
# 47   RSCH        AH - SHINHAN SEKURITAS INDONESIA
# 48   LMAX        AH - SHINHAN SEKURITAS INDONESIA
# 49   GRIA             AO - ERDIKHA ELIT SEKURITAS
# 50   FOLK            HD - KGI SEKURITAS INDONESIA
# 51   PPRI             IU - INDO CAPITAL SEKURITAS
# 52   CYBR    YP - MIRAE ASSET SEKURITAS INDONESIA
# 53   HUMI  LS - RELIANCE SEKURITAS INDONESIA TBK.
# 54   MSIE                      EP - MNC SEKURITAS
# 55   ERAL    YP - MIRAE ASSET SEKURITAS INDONESIA
# 56   HBAT            YJ - LOTUS ANDALAN SEKURITAS
# 57   MUTU  LG - TRIMEGAH SEKURITAS INDONESIA TBK.
# 58   CNMA                  CC - MANDIRI SEKURITAS
# 59   RMKO       MI - VICTORIA SEKURITAS INDONESIA
# 60   MAHA  LG - TRIMEGAH SEKURITAS INDONESIA TBK.
# 61   INET        AH - SHINHAN SEKURITAS INDONESIA
# 62   TGUK         MG - SEMESTA INDOVEST SEKURITAS
# 63   CRSN     XA - NH KORINDO SEKURITAS INDONESIA
# 64   WIDI          SH - ARTHA SEKURITAS INDONESIA
# 65   GRPM     XA - NH KORINDO SEKURITAS INDONESIA
# 66   AMMN                  CC - MANDIRI SEKURITAS
# 67   VKTR           KI - CIPTADANA SEKURITAS ASIA
# 68   RELF             AI - UOB KAY HIAN SEKURITAS
# 69   KLAS               GR - PANIN SEKURITAS TBK.
# 70   MAXI        AH - SHINHAN SEKURITAS INDONESIA
# 71   MPXL               GR - PANIN SEKURITAS TBK.
# 72   JATI            HD - KGI SEKURITAS INDONESIA
# 73   RAAM             AI - UOB KAY HIAN SEKURITAS
# 74   DOOH             IU - INDO CAPITAL SEKURITAS
# 75   TYRE       MI - VICTORIA SEKURITAS INDONESIA
# 76   SMIL                      EP - MNC SEKURITAS
# 77   AWAN         IF - SAMUEL SEKURITAS INDONESIA
# 78   MENN             IU - INDO CAPITAL SEKURITAS
# 79   PIPA        AH - SHINHAN SEKURITAS INDONESIA
# 80   NCKL                  CC - MANDIRI SEKURITAS
# 81   GTRA             AI - UOB KAY HIAN SEKURITAS
# 82   HAJJ              SF - SURYA FAJAR SEKURITAS
# 83   NSSS         IF - SAMUEL SEKURITAS INDONESIA
# 84   CUAN           HP - HENAN PUTIHRAI SEKURITAS
# 85   SAGE          II - DANATAMA MAKMUR SEKURITAS
# 86   TRON              SF - SURYA FAJAR SEKURITAS
# 87   PTMP     XA - NH KORINDO SEKURITAS INDONESIA
# 88   BDKR         MG - SEMESTA INDOVEST SEKURITAS
# 89   FUTR             IU - INDO CAPITAL SEKURITAS
# 90   PGEO                  CC - MANDIRI SEKURITAS
# 91   KING     XA - NH KORINDO SEKURITAS INDONESIA
# 92   CHIP            YJ - LOTUS ANDALAN SEKURITAS
# 93   HALO          II - DANATAMA MAKMUR SEKURITAS
# 94   VAST             AO - ERDIKHA ELIT SEKURITAS
# 95   HILL    YP - MIRAE ASSET SEKURITAS INDONESIA
# 96   PACK     XA - NH KORINDO SEKURITAS INDONESIA
# 97   IRSX        AH - SHINHAN SEKURITAS INDONESIA
# 98   FWCT            YJ - LOTUS ANDALAN SEKURITAS
# 99   NAYZ              SF - SURYA FAJAR SEKURITAS
# 100  PEVE            YJ - LOTUS ANDALAN SEKURITAS
# 101  LAJU     XA - NH KORINDO SEKURITAS INDONESIA
# 102  BMBL            HD - KGI SEKURITAS INDONESIA
# 103  CBPE               GR - PANIN SEKURITAS TBK.
# 104  SOUL        AH - SHINHAN SEKURITAS INDONESIA
# 105  SUNI             AI - UOB KAY HIAN SEKURITAS
# 106  WINE     XA - NH KORINDO SEKURITAS INDONESIA
# 107  ELIT     XA - NH KORINDO SEKURITAS INDONESIA
# 108  BEER             AI - UOB KAY HIAN SEKURITAS
# 109  CBRE            DR - RHB SEKURITAS INDONESIA
# 110  VTNY              SF - SURYA FAJAR SEKURITAS
# 111  PADA             AI - UOB KAY HIAN SEKURITAS
# 112  MMIX    YP - MIRAE ASSET SEKURITAS INDONESIA
# 113  ISAP             AI - UOB KAY HIAN SEKURITAS
# 114  BELI            OD - BRI DANAREKSA SEKURITAS
# 115  KETR        AH - SHINHAN SEKURITAS INDONESIA
# 116  ZATA             AI - UOB KAY HIAN SEKURITAS
# 117  KDTN       MI - VICTORIA SEKURITAS INDONESIA
# 118  NINE              SA - ELIT SUKSES SEKURITAS
# 119  MKTR          II - DANATAMA MAKMUR SEKURITAS
# 120  PRAY             PD - INDO PREMIER SEKURITAS
# 121  CBUT    YP - MIRAE ASSET SEKURITAS INDONESIA
# 122  PDPP         MG - SEMESTA INDOVEST SEKURITAS
# 123  BSBK          SH - ARTHA SEKURITAS INDONESIA
# 124  OMED           KI - CIPTADANA SEKURITAS ASIA
# 125  COAL              SF - SURYA FAJAR SEKURITAS
# 126  MEDS                   AN - WANTEG SEKURITAS
# 127  BUAH  LS - RELIANCE SEKURITAS INDONESIA TBK.
# 128  EURO          II - DANATAMA MAKMUR SEKURITAS
# 129  CRAB            HD - KGI SEKURITAS INDONESIA
# 130  KLIN              SA - ELIT SUKSES SEKURITAS
# 131  KKES    YP - MIRAE ASSET SEKURITAS INDONESIA
# 132  TOOL    YP - MIRAE ASSET SEKURITAS INDONESIA
# 133  RAFI     IN - INVESTINDO NUSANTARA SEKURITAS
# 134  ELPI  LG - TRIMEGAH SEKURITAS INDONESIA TBK.
# 135  JARR     IN - INVESTINDO NUSANTARA SEKURITAS
# 136  RCCC              SA - ELIT SUKSES SEKURITAS
# 137  AMMS             IU - INDO CAPITAL SEKURITAS
# 138  KRYA             IU - INDO CAPITAL SEKURITAS
# 139  AXIO                      NI - BNI SEKURITAS
# 140  HATM     XA - NH KORINDO SEKURITAS INDONESIA
# 141  DEWI            HD - KGI SEKURITAS INDONESIA
# 142  GULA             AI - UOB KAY HIAN SEKURITAS
# 143  CHEM     XA - NH KORINDO SEKURITAS INDONESIA
# 144  TRGU         MG - SEMESTA INDOVEST SEKURITAS
# 145  SWID        AH - SHINHAN SEKURITAS INDONESIA
# 146  ASHA            HD - KGI SEKURITAS INDONESIA
# 147  OLIV          II - DANATAMA MAKMUR SEKURITAS
# 148  IBOS              SF - SURYA FAJAR SEKURITAS
# 149  WINR          SH - ARTHA SEKURITAS INDONESIA
# 150  MTMH           KI - CIPTADANA SEKURITAS ASIA
# 151  TLDN                      NI - BNI SEKURITAS
# 152  GOTO                  CC - MANDIRI SEKURITAS
# 153  SICO     XA - NH KORINDO SEKURITAS INDONESIA
# 154  WIRG           KI - CIPTADANA SEKURITAS ASIA
# 155  BIKE  LG - TRIMEGAH SEKURITAS INDONESIA TBK.
# 156  STAA    DP - DBS VICKERS SEKURITAS INDONESIA
# 157  NANO             AI - UOB KAY HIAN SEKURITAS
# 158  SMKM             AO - ERDIKHA ELIT SEKURITAS
# 159  NTBK              SF - SURYA FAJAR SEKURITAS
# 160  ENAK             AI - UOB KAY HIAN SEKURITAS
# 161  BAUT             AI - UOB KAY HIAN SEKURITAS
# 162  ASLC  LG - TRIMEGAH SEKURITAS INDONESIA TBK.
# 163  NETV     XA - NH KORINDO SEKURITAS INDONESIA
# 164  SEMA     XA - NH KORINDO SEKURITAS INDONESIA
# 165  ADMR           KI - CIPTADANA SEKURITAS ASIA
# 166  IPPE            HD - KGI SEKURITAS INDONESIA
# 167  DRMA                    AZ - SUCOR SEKURITAS
# 168  OBMD            HD - KGI SEKURITAS INDONESIA
# 169  NASI             AI - UOB KAY HIAN SEKURITAS
# 170  BSML          II - DANATAMA MAKMUR SEKURITAS
# 171  AVIA                  CC - MANDIRI SEKURITAS
# 172  CMRY                  CC - MANDIRI SEKURITAS
# 173  RMKE             IU - INDO CAPITAL SEKURITAS
# 174  WMPP              SF - SURYA FAJAR SEKURITAS
# 175  WGSH        AH - SHINHAN SEKURITAS INDONESIA
# 176  DEPO    YP - MIRAE ASSET SEKURITAS INDONESIA
# 177  TAYS     XA - NH KORINDO SEKURITAS INDONESIA
# 178  BINO             IU - INDO CAPITAL SEKURITAS
